# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
clean_data = pd.read_csv('/content/drive/MyDrive/PDS_Assignment_1/Ques_1/data_clean/clean_data.csv')

# %%
plt.hist(clean_data['Height '], bins=20, color='skyblue')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.title('Distribution of Height')
plt.savefig("/content/drive/MyDrive/PDS_Assignment_1/Ques_1/results/height_Distribution.png")

# %%
plt.figure(figsize=(22,7))
plt.subplot(1,2,1)
plt.boxplot(clean_data['Height '])
plt.xlabel('Height')
plt.subplot(1,2,2)
plt.boxplot(clean_data['Grip strength\xa0'])
plt.xlabel('Grip Strength')
plt.savefig("/content/drive/MyDrive/PDS_Assignment_1/Ques_1/results/height_grip_stren_box_plot.png")
